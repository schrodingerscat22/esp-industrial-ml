# %% [markdown]
# # F1: prognozowanie pyłu za 1, 3 i 5 minut
#
# Cienki interfejs do odtwarzalnego wykonawcy. Dane, predykcje i modele pozostają lokalne oraz ignorowane przez Git. Pełny protokół: `docs/forecasting_methodology.md`.

# %%
# Uruchamiaj z korzenia repozytorium; bez argumentów liczy wszystkie foldy i horyzonty.
# %run ../scripts/run_forecasting_experiment.py

# %%
import json
from pathlib import Path

report_path = Path('../data/processed/forecast_v1/report.json')
if report_path.exists():
    report = json.loads(report_path.read_text(encoding='utf-8'))
    print(report['status'], report.get('metrics_rows', 0))
